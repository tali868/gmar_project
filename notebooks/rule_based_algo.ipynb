# %% [markdown]
# # imports

# %%
from core_config_reader_lib import spark_conf

# from datetime import datetime
from typing import Optional

import pandas as pd
from dateutil.relativedelta import relativedelta
from sklearn.model_selection import train_test_split
from pyspark.sql import functions as f, SQLContext, DataFrame
from pyspark.sql.types import *

# %%
import datetime as dt
import json

# %%
pd.set_option('display.max_rows', 100)

# %%
TS = "ts"

# %%
def _save_wanted_time(df: pd.DataFrame, latest_date, months, is_include_last_date=False) -> pd.DataFrame:
    """
    save 2 years in the set
    :return:
    """
    delta = latest_date - relativedelta(months=months)
    if is_include_last_date:
        df = df[(df[TS] >= delta) & (df[TS] <= latest_date)]
    else:
        df = df[(df[TS] >= delta) & (df[TS] < latest_date)]
    return df


def _custom_train_test_split(df: pd.DataFrame, latest_date) -> (pd.DataFrame, pd.DataFrame):
    """
    cuts to ratio of train and set according to the time
    :return:
    """
    cutoff = latest_date - relativedelta(months=3)
    test_df = df[df[TS] >= cutoff]
    train_df = df[df[TS] < cutoff]
    return train_df, test_df


def clean_and_split_df(df: pd.DataFrame) -> (pd.DataFrame, pd.DataFrame):
    df = df[df['next_pc'].notna()]
    df[TS] = pd.to_datetime(df[TS], format='%Y-%m-%d %H:%M:%S')
    # df[TS] = df[TS].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
    latest_date = df[TS].max()
    df = _save_wanted_time(df, latest_date, 24, is_include_last_date=True)
    # train_df, test_df = _custom_train_test_split(df, latest_date)
    df = df.sort_values(by=["ts"], ascending=True)
#     train_df, test_df = train_test_split(df, test_size=0.2, shuffle=False)
#     return train_df, test_df
    return df


def get_last_year_resolved_to_pc(vessel_df: pd.DataFrame, timestamp) -> Optional[list]:
    last_year_df = _save_wanted_time(vessel_df, timestamp, 12)
    if last_year_df.empty or abs(
            (timestamp - last_year_df[TS].max()).days) < 90:  # if there is no delta of days or there is less than three months of data
        return None
    all_history = last_year_df.apply(
        lambda x: [x["destination"], x["resolved_dest"], x["next_pc"]], axis=1).tolist()
    return all_history

# %%
all_points_df = pd.read_csv("enriched_destinations.csv")

# %%
print(f"Cleaning and splitting df to train and test sets")
all_points_df = clean_and_split_df(all_points_df)
print(f"In train there are {all_points_df.shape[0]} rows")
# print(f"In test there are {test_points_df.shape[0]} rows")
# Out:
# Cleaning and splitting df to train and test sets
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# In train there are 1178830 rows

# %% [markdown]
# # create data

# %% [markdown]
# ## prepare dataset

# %%
vessels_df = all_points_df.groupby("vessel_id")

# %%
final = []

for vessel, vessel_df in all_points_df.groupby("vessel_id"):
    sorted_df = vessel_df.sort_values("ts")
    tupled = vessel_df[["ts", "destination", "resolved_dest", "next_pc"]].values.tolist()
    final.append((vessel, tupled))

# %%
print(f"There are {len(final)} vessels after group by")
# Out:
# There are 5445 vessels after group by

# %% [markdown]
# ### Cut each history per time (1 year before ts)

# %%
from tqdm import tqdm
import datetime as dt

def find_latest_point(min_ts, tuples):
    for ix, point in enumerate(tuples):
        if (point[0] - dt.timedelta(365 + 1) > min_ts):
            return ix
    return None
        

per_vessel = []

for i in tqdm(range(0, len(final)), desc ="per_vessel"):
    tuples = final[i][1]
    min_ts = tuples[0][0]
    vessel = final[i][0]
    wanted = []
    last_ts_ix = 0
    for j in range(1, len(tuples)):
        ts = tuples[j][0]
        if (ts > min_ts + dt.timedelta(365 + 1)):
            wanted.append(tuples[0:j])
            continue
    per_vessel.append([vessel, wanted])
# Out:
# per_vessel: 100%|██████████| 5445/5445 [00:07<00:00, 736.85it/s]

# %%
def find_first(tuples, last_ts, ix):
    if ix >= len(tuples):
        return len(tuples)
    first_ts = tuples[ix][0]
    if (last_ts - first_ts).days < 365 + 1:
        return ix
    return find_first(tuples, last_ts, ix+1)

clean_per_vessel = []
for vessel, points_list in tqdm(per_vessel):
    blah = []
    for tuples in points_list:
        last_ts = tuples[-1][0]
        first_ts = tuples[0][0]
        first_ix = find_first(tuples, last_ts, 0)
        blah.append(tuples[first_ix:])
    clean_per_vessel.append([vessel, blah])
# Out:
#   6%|▌         | 309/5445 [00:14<03:58, 21.53it/s]

# %% [markdown]
# ## start rule-based

# %% [markdown]
# ### Get only visit history that matches reported destination

# %%
personilized_prediction = []

for vessel, points_list in tqdm(clean_per_vessel):
    for tuples in points_list:
        last_point = tuples[-1]
        reported = last_point[1]
        suggested_dest = last_point[2]
        real_dest = last_point[3]
        match = True if real_dest == suggested_dest else False
        timestamp = last_point[0]
        found_destinations = []
        for point in tuples[:-1]:
            if point[1] == reported:  # TODO - this like is 1:1 match!!!
                found_destinations.append(
                    {"baseline": point[2], "actual_pc": point[3]})
        personilized_prediction.append({"vessel": vessel, "reported": reported,
                                       "suggested_dest": suggested_dest, "real_dest": real_dest, "match": match,
                                        "ts": timestamp, "found_destinations": found_destinations})
# Out:
# 100%|██████████| 5445/5445 [00:13<00:00, 412.44it/s]

# %%
print(f"There are {len(personilized_prediction)} individual, per vessel, timestamp and reported destination.")
# Out:
# There are 547743 individual, per vessel, timestamp and reported destination.

# %% [markdown]
# ### create visit history count (actual logic application)

# %%
def actual_logic_func(suggested_dest, found_destinations):
    if not found_destinations:
        return None
    
    if is_nan(suggested_dest):
        return None
    
    suggested = {}
    for baseline_vs_real in found_destinations:
        if suggested_dest != baseline_vs_real["actual_pc"]:
            if baseline_vs_real["actual_pc"] in suggested:
                suggested[baseline_vs_real["actual_pc"]] += 1
            else:
                suggested[baseline_vs_real["actual_pc"]] = 1
        elif suggested_dest == baseline_vs_real["actual_pc"]:
            if "baseline" in suggested:
                suggested["baseline"] += 1
            else:
                suggested["baseline"] = 1
    
    return suggested if len(suggested) != 0 else None

# %%
def is_nan(x):
    return (x != x)

for ix in range(0, len(personilized_prediction)):
    per_vessel = personilized_prediction[ix]
    res = actual_logic_func(per_vessel["suggested_dest"], per_vessel["found_destinations"])
    personilized_prediction[ix]["new"] = res

# %%
personilized_prediction[0]["ts"].isoformat()
# Out:
# '2021-09-05T19:54:40'

# %%
# count = 0
# bigger_len = 0
# for vessel in personilized_prediction:
#     if vessel["new"]:
#         blah = str(vessel["new"])
#         if blah != "[nan]" and count < 50:
#             count += 1
#             print(vessel["new"])

# %% [markdown]
# ## write results

# %%
def serialize_timestamp(obj):
    if isinstance(obj, pd.Timestamp):
        return obj.isoformat()
    raise TypeError

# %%
with open("personalized.json", mode="w") as f:
    json.dump(personilized_prediction, f, default=serialize_timestamp)

# %% [markdown]
# # read data to pandas

# %%
def deserialize_timestamp(obj):
    if isinstance(obj, str) and "-" in obj and ":" in obj and "T" in obj:
        return pd.Timestamp(obj)
    return obj

# %%
with open("personalized.json", mode="r") as f:
    raw_personilized_prediction = json.load(f)

# %%
raw_personilized_prediction[0]
# Out:
# {'vessel': '513a7b806ca0bbcb46a5a1e3',
#  'reported': 'JP SBK',
#  'suggested_dest': '5358fc78b68ca120a07dbbc9',
#  'real_dest': '5358fc78b68ca120a07dbbc9',
#  'match': True,
#  'ts': '2021-09-05T19:54:40',
#  'found_destinations': [{'baseline': '5358fc78b68ca120a07dbbc9',
#    'actual_pc': '5358fc78b68ca120a07dbbc9'},
#   {'baseline': '5358fc78b68ca120a07dbbc9',
#    'actual_pc': '5358fc78b68ca120a07dbbc9'},
#   {'baseline': '5358fc78b68ca120a07dbbc9',
#    'actual_pc': '5358fc78b68ca120a07dbcbb'},
#   {'baseline': '5358fc78b68ca120a07dbbc9',
#    'actual_pc': '5358fc78b68ca120a07dbcbb'},
#   {'baseline': '5358fc78b68ca120a07dbbc9',
#    'actual_pc': '5358fc78b68ca120a07dbbc9'}],
#  'new': {'baseline': 3, '5358fc78b68ca120a07dbcbb': 2}}

# %%
personilized_prediction_df = pd.DataFrame(raw_personilized_prediction)

# %%
personilized_prediction_df[TS] = pd.to_datetime(personilized_prediction_df[TS],format='%Y-%m-%dT%H:%M:%S')

# %%
personilized_prediction_df[:2]
# Out:
#                      vessel  reported            suggested_dest  \
# 0  513a7b806ca0bbcb46a5a1e3    JP SBK  5358fc78b68ca120a07dbbc9
# 1  513a7b806ca0bbcb46a5a1e3  JP OSA H  5358fc78b68ca120a07dbcbb
#
#                   real_dest  match                  ts  \
# 0  5358fc78b68ca120a07dbbc9   True 2021-09-05 19:54:40
# 1  5358fc78b68ca120a07dbcbb   True 2021-09-08 07:23:00
#
#                                   found_destinations  \
# 0  [{'baseline': '5358fc78b68ca120a07dbbc9', 'act...
# 1  [{'baseline': '5358fc78b68ca120a07dbcbb', 'act...
#
#                                               new
# 0  {'baseline': 3, '5358fc78b68ca120a07dbcbb': 2}
# 1                                 {'baseline': 1}

# %% [markdown]
# ## what to return

# %%
def match_best_prediction(suggested_dest, predicted_list: dict):
    max_visits_count = 0
    max_visits_polygon = None
    if predicted_list is None:
        return None
    
    for polygon, count in predicted_list.items():
        if polygon == "baseline":
            return suggested_dest
        else:
            if count > max_visits_count:
                max_visits_count = count
                max_visits_polygon = polygon
    return max_visits_polygon


def match_best_prediction_without_baseline(suggested_dest, predicted_list: dict):
    max_visits_count = 0
    max_visits_polygon = None
    if predicted_list is None:
        return None
    
    for polygon, count in predicted_list.items():
        if count > max_visits_count:
            max_visits_count = count
            max_visits_polygon = polygon
    return max_visits_polygon if max_visits_polygon != "baseline" else suggested_dest

# %%
personilized_prediction_df["new_suggestion"] = personilized_prediction_df[["suggested_dest", "new"]].apply(
    lambda x: match_best_prediction(x["suggested_dest"], x["new"]), axis=1)

# %%
personilized_prediction_df["without_baseline"] = personilized_prediction_df[["suggested_dest", "new"]].apply(
    lambda x: match_best_prediction_without_baseline(x["suggested_dest"], x["new"]), axis=1)

# %%
clean_personilized_prediction_df = personilized_prediction_df[personilized_prediction_df.apply(lambda x: x["new"] is not None, axis=1)]

# %%
personilized_prediction_df = personilized_prediction_df.rename(columns={"suggested_dest": "bl_dest", 
                                           "new_suggestion": "suggested_dest", 
                                           "without_baseline": "suggested_no_bl_dest",
                                           "match": "bl_match"})

# %%
personilized_prediction_df["suggested_match"] = personilized_prediction_df["suggested_dest"] == personilized_prediction_df["real_dest"]
personilized_prediction_df["bl_match"] = personilized_prediction_df["bl_dest"] == personilized_prediction_df["real_dest"]
personilized_prediction_df["suggested_no_base_match"] = personilized_prediction_df["suggested_no_bl_dest"] == personilized_prediction_df["real_dest"]
personilized_prediction_df["bl_suggested"] = personilized_prediction_df["suggested_dest"] == personilized_prediction_df["bl_dest"]

# %%
personilized_prediction_df
# Out:
#                           vessel  reported                   bl_dest  \
# 0       513a7b806ca0bbcb46a5a1e3    JP SBK  5358fc78b68ca120a07dbbc9
# 1       513a7b806ca0bbcb46a5a1e3  JP OSA H  5358fc78b68ca120a07dbcbb
# 2       513a7b806ca0bbcb46a5a1e3    JP UKB  5358fc78b68ca120a07dbc9e
# 3       513a7b806ca0bbcb46a5a1e3    KR PUS  5358fc78b68ca120a07dbc71
# 4       513a7b806ca0bbcb46a5a1e3    CN SHA  5358fc78b68ca120a07dbcfb
# ...                          ...       ...                       ...
# 547738  62d6e20e6e5c10c029df7f37     IDSRI  5358fc78b68ca120a07db74f
# 547739  62d6e20e6e5c10c029df7f37    ID SUB  5358fc78b68ca120a07dbc01
# 547740  62d6e20e6e5c10c029df7f37    ID SRI  5358fc78b68ca120a07db74f
# 547741  62d6e20e6e5c10c029df7f37    ID SUB  5358fc78b68ca120a07dbc01
# 547742  62d6e20e6e5c10c029df7f37     IDSRI  5358fc78b68ca120a07db74f
#
#                        real_dest  bl_match                  ts  \
# 0       5358fc78b68ca120a07dbbc9      True 2021-09-05 19:54:40
# 1       5358fc78b68ca120a07dbcbb      True 2021-09-08 07:23:00
# 2       5358fc78b68ca120a07dbc9e      True 2021-09-08 19:54:40
# 3       5358fc78b68ca120a07dbc71      True 2021-09-09 13:45:35
# 4       5358fc78b68ca120a07dbcfb      True 2021-09-11 05:47:44
# ...                          ...       ...                 ...
# 547738  5358fc78b68ca120a07db74f      True 2022-08-07 13:50:38
# 547739  5358fc78b68ca120a07dbc01      True 2022-08-12 07:45:02
# 547740  5358fc78b68ca120a07db74f      True 2022-08-15 08:11:07
# 547741  5358fc78b68ca120a07dbc01      True 2022-08-20 07:59:57
# 547742  5358fc78b68ca120a07db74f      True 2022-08-29 05:11:22
#
#                                        found_destinations  \
# 0       [{'baseline': '5358fc78b68ca120a07dbbc9', 'act...
# 1       [{'baseline': '5358fc78b68ca120a07dbcbb', 'act...
# 2       [{'baseline': '5358fc78b68ca120a07dbc9e', 'act...
# 3       [{'baseline': '5358fc78b68ca120a07dbc71', 'act...
# 4       [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# ...                                                   ...
# 547738                                                 []
# 547739  [{'baseline': '5358fc78b68ca120a07dbc01', 'act...
# 547740  [{'baseline': '5358fc78b68ca120a07db74f', 'act...
# 547741  [{'baseline': '5358fc78b68ca120a07dbc01', 'act...
# 547742  [{'baseline': '5358fc78b68ca120a07db74f', 'act...
#
#                                                     new  \
# 0        {'baseline': 3, '5358fc78b68ca120a07dbcbb': 2}
# 1                                       {'baseline': 1}
# 2                                       {'baseline': 4}
# 3                                       {'baseline': 3}
# 4                                      {'baseline': 15}
# ...                                                 ...
# 547738                                             None
# 547739                                 {'baseline': 19}
# 547740  {'baseline': 21, '5358fc78b68ca120a07dbc01': 5}
# 547741                                 {'baseline': 20}
# 547742                                  {'baseline': 1}
#
#                   suggested_dest      suggested_no_bl_dest  suggested_match_2  \
# 0       5358fc78b68ca120a07dbbc9  5358fc78b68ca120a07dbbc9               True
# 1       5358fc78b68ca120a07dbcbb  5358fc78b68ca120a07dbcbb               True
# 2       5358fc78b68ca120a07dbc9e  5358fc78b68ca120a07dbc9e               True
# 3       5358fc78b68ca120a07dbc71  5358fc78b68ca120a07dbc71               True
# 4       5358fc78b68ca120a07dbcfb  5358fc78b68ca120a07dbcfb               True
# ...                          ...                       ...                ...
# 547738                      None                      None              False
# 547739  5358fc78b68ca120a07dbc01  5358fc78b68ca120a07dbc01               True
# 547740  5358fc78b68ca120a07db74f  5358fc78b68ca120a07db74f               True
# 547741  5358fc78b68ca120a07dbc01  5358fc78b68ca120a07dbc01               True
# 547742  5358fc78b68ca120a07db74f  5358fc78b68ca120a07db74f               True
#
#         suggested_no_base_match  bl_suggested  suggested_match
# 0                          True          True             True
# 1                          True          True             True
# 2                          True          True             True
# 3                          True          True             True
# 4                          True          True             True
# ...                         ...           ...              ...
# 547738                    False         False            False
# 547739                     True          True             True
# 547740                     True          True             True
# 547741                     True          True             True
# 547742                     True          True             True
#
# [547743 rows x 14 columns]

# %%
personilized_prediction_df[personilized_prediction_df["bl_match"] == False][:40]
# Out:
#                        vessel          reported                   bl_dest  \
# 7    513a7b806ca0bbcb46a5a1e3            KH SHV  5358fc78b68ca120a07db7cb
# 51   513a7b806ca0bbcb46a5a1e3            CN NGB  5358fc78b68ca120a07db9f4
# 64   513a7b806ca0bbcb46a5a1e3            TH LCH  54880c9b2f16092e9efe8a43
# 51   [{'baseline': '5358fc78b68ca120a07db9f4', 'act...
# 64   [{'baseline': '54880c9b2f16092e9efe8a43', 'act...
# 83   [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 99   [{'baseline': '5358fc78b68ca120a07dbaa9', 'act...
# 118                                                 []
# 119  [{'baseline': '5358fc78b68ca120a07dbcff', 'act...
# 169  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 178  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 189  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 197  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 212  [{'baseline': '57c539e9447c1ee77504c390', 'act...
# 226  [{'baseline': '57c539e9447c1ee77504c390', 'act...
# 228  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 254  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 280  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 296  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 319  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 323  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 329  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 356  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 360  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 369  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 387  [{'baseline': '5358fc78b68ca120a07dbc99', 'act...
# 393  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 401  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 416  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 418  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 433  [{'baseline': '537ca63f72ef82043d62100f', 'act...
# 437  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 450  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 464  [{'baseline': '5358fc78b68ca120a07dbce5', 'act...
# 471  [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 474                                                 []
# 477  [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 485  [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 493  [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 495                                                 []
# 501  [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 502                                                 []
#
#                                                    new  \
# 7       {'54880c9b2f16092e9efe8a3f': 1, 'baseline': 5}
# 51      {'5358fc78b68ca120a07dbcfb': 1, 'baseline': 8}
# 64                                    {'baseline': 14}
# 83                                    {'baseline': 15}
# 99     {'baseline': 21, '5358fc78b68ca120a07dbc52': 1}
# 118                                               None
# 119                                    {'baseline': 3}
# 169                   {'57c539e9447c1ee77504c390': 24}
# 178                   {'57c539e9447c1ee77504c390': 25}
# 189                   {'57c539e9447c1ee77504c390': 26}
# 197                   {'57c539e9447c1ee77504c390': 27}
# 212                                   {'baseline': 33}
# 226    {'baseline': 32, '5358fc78b68ca120a07dbc52': 1}
# 228                                   {'baseline': 25}
# 254    {'baseline': 69, '5358fc78b68ca120a07dbc09': 1}
# 280                   {'57c539e9447c1ee77504c390': 23}
# 296    {'baseline': 27, '5358fc78b68ca120a07dbc99': 1}
# 319                   {'57c539e9447c1ee77504c390': 20}
# 323    {'baseline': 28, '5358fc78b68ca120a07dbc99': 2}
# 329  {'baseline': 29, '5358fc78b68ca120a07dbc99': 2...
# 356    {'baseline': 54, '5358fc78b68ca120a07dbc09': 1}
# 360                   {'57c539e9447c1ee77504c390': 15}
# 369  {'baseline': 32, '5358fc78b68ca120a07dbc99': 3...
# 387    {'baseline': 74, '5358fc78b68ca120a07dbc52': 1}
# 393                    {'57c539e9447c1ee77504c390': 9}
# 401                   {'57c539e9447c1ee77504c390': 10}
# 416                   {'57c539e9447c1ee77504c390': 11}
# 418    {'baseline': 44, '5358fc78b68ca120a07dbc09': 2}
# 433                   {'57c539e9447c1ee77504c390': 12}
# 437  {'baseline': 43, '5358fc78b68ca120a07dbc09': 2...
# 450  {'baseline': 43, '5358fc78b68ca120a07dbc09': 3...
# 464                                    {'baseline': 8}
# 471                    {'5358fc78b68ca120a07db97e': 2}
# 474                                               None
# 477                    {'5358fc78b68ca120a07db97e': 3}
# 485                    {'5358fc78b68ca120a07db97e': 4}
# 493                    {'5358fc78b68ca120a07db97e': 5}
# 495                                               None
# 501  {'5358fc78b68ca120a07db97e': 5, '5358fc78b68ca...
# 502                                               None
#
#                suggested_dest      suggested_no_bl_dest  suggested_match  \
# 7    5358fc78b68ca120a07db7cb  5358fc78b68ca120a07db7cb            False
# 51   5358fc78b68ca120a07db9f4  5358fc78b68ca120a07db9f4            False
# 64   54880c9b2f16092e9efe8a43  54880c9b2f16092e9efe8a43            False
# 83   5358fc78b68ca120a07dbcfb  5358fc78b68ca120a07dbcfb            False
# 99   5358fc78b68ca120a07dbaa9  5358fc78b68ca120a07dbaa9            False
# 118                      None                      None            False
# 119  5358fc78b68ca120a07dbcff  5358fc78b68ca120a07dbcff            False
# 169  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 178  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 189  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 197  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 212  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390            False
# 226  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390            False
# 228  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 254  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 280  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 296  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 319  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 323  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 329  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 356  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 360  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 369  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 387  5358fc78b68ca120a07dbc99  5358fc78b68ca120a07dbc99            False
# 393  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 401  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 416  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 418  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 433  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390             True
# 437  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 450  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52            False
# 464  5358fc78b68ca120a07dbce5  5358fc78b68ca120a07dbce5            False
# 471  5358fc78b68ca120a07db97e  5358fc78b68ca120a07db97e             True
# 474                      None                      None            False
# 477  5358fc78b68ca120a07db97e  5358fc78b68ca120a07db97e             True
# 485  5358fc78b68ca120a07db97e  5358fc78b68ca120a07db97e             True
# 493  5358fc78b68ca120a07db97e  5358fc78b68ca120a07db97e            False
# 495                      None                      None            False
# 501  5358fc78b68ca120a07db97e  5358fc78b68ca120a07db97e             True
# 502                      None                      None            False
#
#      suggested_no_base_match  bl_suggested
# 7                      False          True
# 51                     False          True
# 64                     False          True
# 83                     False          True
# 99                     False          True
# 118                    False         False
# 119                    False          True
# 169                     True         False
# 178                     True         False
# 189                     True         False
# 197                     True         False
# 212                    False          True
# 226                    False          True
# 228                    False          True
# 254                    False          True
# 280                     True         False
# 296                    False          True
# 319                     True         False
# 323                    False          True
# 329                    False          True
# 356                    False          True
# 360                     True         False
# 369                    False          True
# 387                    False          True
# 393                     True         False
# 401                     True         False
# 416                     True         False
# 418                    False          True
# 433                     True         False
# 437                    False          True
# 450                    False          True
# 464                    False          True
# 471                     True         False
# 474                    False         False
# 477                     True         False
# 485                     True         False
# 493                    False         False
# 495                    False         False
# 501                     True         False
# 502                    False         False

# %%
port_names_df = pd.DataFrame([{"port_name": "Savannah", "polygon": "5358fc78b68ca120a07dbbdc"}, 
                              {"port_name": "SanDiego", "polygon": "5358fc78b68ca120a07dbcf8"},
                              {"port_name": "Manzanillo_mexico", "polygon": "5358fc78b68ca120a07dbb1c"},
                              {"port_name": "Manzanillo_panama", "polygon": "5fe89bca62e5fd434e77136f"}])

# %%
port_names_df
# Out:
#            port_name                   polygon
# 0           Savannah  5358fc78b68ca120a07dbbdc
# 1           SanDiego  5358fc78b68ca120a07dbcf8
# 2  Manzanillo_mexico  5358fc78b68ca120a07dbb1c
# 3  Manzanillo_panama  5fe89bca62e5fd434e77136f

# %%
example_1_df = personilized_prediction_df[(personilized_prediction_df["bl_match"] == False) & (personilized_prediction_df["suggested_match"] == True) & (personilized_prediction_df["vessel"] == "5905c34ca696e258790228f3")][["ts", "vessel", "reported", "bl_dest", "real_dest", "suggested_dest", "suggested_match", "bl_match"]]

# %%
manzanillo_example_df = personilized_prediction_df[(personilized_prediction_df["real_dest"] == "5358fc78b68ca120a07dbb1c") & 
                           (personilized_prediction_df["bl_dest"] == "5fe89bca62e5fd434e77136f") & 
                           (personilized_prediction_df["vessel"] == "5e1ee618b6f99132279a307f") & 
                           (personilized_prediction_df["suggested_match"] == True) & 
                          (personilized_prediction_df["bl_match"] == False)][["ts", "vessel", "reported", "bl_dest", "real_dest", "suggested_dest", "suggested_match", "bl_match"]]

# %%
manzanillo_example_df.merge(port_names_df, left_on=["bl_dest"], right_on=[
                            "polygon"]).rename(columns={"port_name": "bl_name"}).merge(
    port_names_df, left_on=["real_dest"], right_on=["polygon"]).rename(columns={"port_name": "real_name"}).merge(
    port_names_df, left_on=["suggested_dest"], right_on=["polygon"]).rename(columns={"port_name": "suggested_name"})[
    ["ts", "vessel", "reported", "bl_name", "real_name", "suggested_name", "bl_match", "suggested_match"]
].sort_values(TS)
# Out:
#           ts                    vessel    reported            bl_name  \
# 0 2022-02-01  5e1ee618b6f99132279a307f  MANZANILLO  Manzanillo_panama
#
#            real_name     suggested_name  bl_match  suggested_match
# 0  Manzanillo_mexico  Manzanillo_mexico     False             True

# %%
manzanillo_example_df
# Out:
#                         ts                    vessel    reported  \
# 21337  2022-07-01 00:00:00  5905c346e07bb7588d9c76f7  MANZANILLO
# 92235  2022-07-01 00:00:00  5905c34b71379e57e146101f  MANZANILLO
# 96415  2022-08-01 00:00:00  5905c34bca83c24c8075c6db  MANZANILLO
# 96426  2022-08-25 00:22:25  5905c34bca83c24c8075c6db  MANZANILLO
# 100549 2021-09-23 06:30:24  5905c34c0328b758c69a58e4  MANZANILLO
# 100550 2021-10-01 00:00:00  5905c34c0328b758c69a58e4  MANZANILLO
# 100554 2021-10-25 11:44:05  5905c34c0328b758c69a58e4  MANZANILLO
# 106892 2022-05-14 08:23:35  5905c34c4558b758c2f709cb  MANZANILLO
# 113676 2021-09-24 01:51:15  5905c34cd548704c81b04592  MANZANILLO
# 113677 2021-10-01 00:00:00  5905c34cd548704c81b04592  MANZANILLO
# 113732 2022-06-16 22:57:41  5905c34cd548704c81b04592  MANZANILLO
# 114581 2021-10-31 01:04:27  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114582 2021-11-01 00:00:00  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114590 2021-12-06 01:10:03  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114603 2022-01-30 14:11:02  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114604 2022-02-01 00:00:00  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114616 2022-03-20 16:23:59  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114618 2022-03-28 01:35:33  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 114628 2022-05-05 16:50:05  5905c34ce40cb74c8b4dc4c2  MANZANILLO
# 205023  5358fc78b68ca120a07dbb1c             True     False
# 242067  5358fc78b68ca120a07dbb1c             True     False
# 242068  5358fc78b68ca120a07dbb1c             True     False
# 314166  5358fc78b68ca120a07dbb1c             True     False
# 314181  5358fc78b68ca120a07dbb1c             True     False
# 339712  5358fc78b68ca120a07dbb1c             True     False
# 339726  5358fc78b68ca120a07dbb1c             True     False
# 339741  5358fc78b68ca120a07dbb1c             True     False
# 339755  5358fc78b68ca120a07dbb1c             True     False
# 339757  5358fc78b68ca120a07dbb1c             True     False
# 339759  5358fc78b68ca120a07dbb1c             True     False
# 343443  5358fc78b68ca120a07dbb1c             True     False
# 345118  5358fc78b68ca120a07dbb1c             True     False
# 345123  5358fc78b68ca120a07dbb1c             True     False
# 345128  5358fc78b68ca120a07dbb1c             True     False
# 345133  5358fc78b68ca120a07dbb1c             True     False
# 345142  5358fc78b68ca120a07dbb1c             True     False
# 345146  5358fc78b68ca120a07dbb1c             True     False
# 351692  5358fc78b68ca120a07dbb1c             True     False
# 355347  5358fc78b68ca120a07dbb1c             True     False
# 375709  5358fc78b68ca120a07dbb1c             True     False
# 391962  5358fc78b68ca120a07dbb1c             True     False
# 391970  5358fc78b68ca120a07dbb1c             True     False
# 391980  5358fc78b68ca120a07dbb1c             True     False
# 391981  5358fc78b68ca120a07dbb1c             True     False
# 391992  5358fc78b68ca120a07dbb1c             True     False
# 392004  5358fc78b68ca120a07dbb1c             True     False
# 392013  5358fc78b68ca120a07dbb1c             True     False
# 392014  5358fc78b68ca120a07dbb1c             True     False
# 392034  5358fc78b68ca120a07dbb1c             True     False
# 399058  5358fc78b68ca120a07dbb1c             True     False
# 399059  5358fc78b68ca120a07dbb1c             True     False
# 399067  5358fc78b68ca120a07dbb1c             True     False
# 402327  5358fc78b68ca120a07dbb1c             True     False
# 432794  5358fc78b68ca120a07dbb1c             True     False
# 434597  5358fc78b68ca120a07dbb1c             True     False
# 434608  5358fc78b68ca120a07dbb1c             True     False
# 434613  5358fc78b68ca120a07dbb1c             True     False
# 435097  5358fc78b68ca120a07dbb1c             True     False
# 435105  5358fc78b68ca120a07dbb1c             True     False
# 442970  5358fc78b68ca120a07dbb1c             True     False
# 444610  5358fc78b68ca120a07dbb1c             True     False
# 446047  5358fc78b68ca120a07dbb1c             True     False
# 446056  5358fc78b68ca120a07dbb1c             True     False
# 446061  5358fc78b68ca120a07dbb1c             True     False
# 467221  5358fc78b68ca120a07dbb1c             True     False
# 467222  5358fc78b68ca120a07dbb1c             True     False
# 469629  5358fc78b68ca120a07dbb1c             True     False
# 486349  5358fc78b68ca120a07dbb1c             True     False
# 486353  5358fc78b68ca120a07dbb1c             True     False
# 487524  5358fc78b68ca120a07dbb1c             True     False
# 487543  5358fc78b68ca120a07dbb1c             True     False
# 488412  5358fc78b68ca120a07dbb1c             True     False
# 491640  5358fc78b68ca120a07dbb1c             True     False
# 491653  5358fc78b68ca120a07dbb1c             True     False
# 491654  5358fc78b68ca120a07dbb1c             True     False
# 491697  5358fc78b68ca120a07dbb1c             True     False
# 491698  5358fc78b68ca120a07dbb1c             True     False
# 491716  5358fc78b68ca120a07dbb1c             True     False
# 502171  5358fc78b68ca120a07dbb1c             True     False
# 502190  5358fc78b68ca120a07dbb1c             True     False
# 502191  5358fc78b68ca120a07dbb1c             True     False
# 530764  5358fc78b68ca120a07dbb1c             True     False
# 542952  5358fc78b68ca120a07dbb1c             True     False

# %%
example_df = personilized_prediction_df[(personilized_prediction_df["bl_match"] == False) & (personilized_prediction_df["suggested_match"] == True) & (personilized_prediction_df["vessel"] == "59091202de94e903c6af3a2f")][["ts", "vessel", "reported", "bl_dest", "real_dest", "suggested_dest", "suggested_match", "bl_match"]]

# %%
example_df
# Out:
#                         ts                    vessel reported  \
# 462907 2021-10-05 12:44:46  59091202de94e903c6af3a2f   US SAN
# 462911 2021-10-26 16:52:30  59091202de94e903c6af3a2f   US SAN
# 462916 2021-11-17 07:38:01  59091202de94e903c6af3a2f   US SAN
# 462921 2021-12-07 12:33:34  59091202de94e903c6af3a2f   US SAN
# 462925 2021-12-28 12:21:34  59091202de94e903c6af3a2f   US SAN
# 462926 2022-01-01 00:00:00  59091202de94e903c6af3a2f   US SAN
# 462931 2022-01-18 12:55:12  59091202de94e903c6af3a2f   US SAN
# 462936 2022-02-08 10:57:31  59091202de94e903c6af3a2f   US SAN
# 462942 2022-03-01 13:03:34  59091202de94e903c6af3a2f   US SAN
# 462946 2022-03-22 23:21:28  59091202de94e903c6af3a2f   US SAN
# 462949 2022-04-12 21:47:10  59091202de94e903c6af3a2f   US SAN
# 462954 2022-05-04 18:40:31  59091202de94e903c6af3a2f   US SAN
# 462959 2022-05-24 20:07:35  59091202de94e903c6af3a2f   US SAN
# 462964 2022-06-14 12:54:35  59091202de94e903c6af3a2f   US SAN
#
#                          bl_dest                 real_dest  \
# 462907  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462911  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462916  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462921  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462925  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462926  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462931  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462936  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462942  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462946  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462949  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462954  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462959  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
# 462964  5358fc78b68ca120a07dbbdc  5358fc78b68ca120a07dbcf8
#
#                   suggested_dest  suggested_match  bl_match
# 462907  5358fc78b68ca120a07dbcf8             True     False
# 462911  5358fc78b68ca120a07dbcf8             True     False
# 462916  5358fc78b68ca120a07dbcf8             True     False
# 462921  5358fc78b68ca120a07dbcf8             True     False
# 462925  5358fc78b68ca120a07dbcf8             True     False
# 462926  5358fc78b68ca120a07dbcf8             True     False
# 462931  5358fc78b68ca120a07dbcf8             True     False
# 462936  5358fc78b68ca120a07dbcf8             True     False
# 462942  5358fc78b68ca120a07dbcf8             True     False
# 462946  5358fc78b68ca120a07dbcf8             True     False
# 462949  5358fc78b68ca120a07dbcf8             True     False
# 462954  5358fc78b68ca120a07dbcf8             True     False
# 462959  5358fc78b68ca120a07dbcf8             True     False
# 462964  5358fc78b68ca120a07dbcf8             True     False

# %%
manzanillo_example_df.merge(port_names_df, left_on=["bl_dest"], right_on=[
                            "polygon"]).rename(columns={"port_name": "bl_name"}).merge(
    port_names_df, left_on=["real_dest"], right_on=["polygon"]).rename(columns={"port_name": "real_name"}).merge(
    port_names_df, left_on=["suggested_dest"], right_on=["polygon"]).rename(columns={"port_name": "suggested_name"})[
    ["ts", "vessel", "reported", "bl_name", "real_name", "suggested_name", "bl_match", "suggested_match"]
].sort_values(TS)
# Out:
#                     ts                    vessel reported   bl_name real_name  \
# 0  2021-10-05 12:44:46  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 1  2021-10-26 16:52:30  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 2  2021-11-17 07:38:01  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 3  2021-12-07 12:33:34  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 4  2021-12-28 12:21:34  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 5  2022-01-01 00:00:00  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 6  2022-01-18 12:55:12  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 7  2022-02-08 10:57:31  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 8  2022-03-01 13:03:34  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 9  2022-03-22 23:21:28  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 10 2022-04-12 21:47:10  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 11 2022-05-04 18:40:31  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 12 2022-05-24 20:07:35  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 13 2022-06-14 12:54:35  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
#
#    suggested_name  bl_match  suggested_match
# 0        SanDiego     False             True
# 1        SanDiego     False             True
# 2        SanDiego     False             True
# 3        SanDiego     False             True
# 4        SanDiego     False             True
# 5        SanDiego     False             True
# 6        SanDiego     False             True
# 7        SanDiego     False             True
# 8        SanDiego     False             True
# 9        SanDiego     False             True
# 10       SanDiego     False             True
# 11       SanDiego     False             True
# 12       SanDiego     False             True
# 13       SanDiego     False             True

# %%
example_df.merge(port_names_df, left_on=["bl_dest"], right_on=[
                            "polygon"]).rename(columns={"port_name": "bl_name"}).merge(
    port_names_df, left_on=["real_dest"], right_on=["polygon"]).rename(columns={"port_name": "real_name"}).merge(
    port_names_df, left_on=["suggested_dest"], right_on=["polygon"]).rename(columns={"port_name": "suggested_name"})[
    ["ts", "vessel", "reported", "bl_name", "real_name", "suggested_name", "bl_match", "suggested_match"]
].sort_values(TS)
# Out:
#                     ts                    vessel reported   bl_name real_name  \
# 0  2021-10-05 12:44:46  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 1  2021-10-26 16:52:30  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 2  2021-11-17 07:38:01  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 3  2021-12-07 12:33:34  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 4  2021-12-28 12:21:34  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 5  2022-01-01 00:00:00  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 6  2022-01-18 12:55:12  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 7  2022-02-08 10:57:31  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 8  2022-03-01 13:03:34  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 9  2022-03-22 23:21:28  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 10 2022-04-12 21:47:10  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 11 2022-05-04 18:40:31  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 12 2022-05-24 20:07:35  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
# 13 2022-06-14 12:54:35  59091202de94e903c6af3a2f   US SAN  Savannah  SanDiego
#
#    suggested_name  bl_match  suggested_match
# 0        SanDiego     False             True
# 1        SanDiego     False             True
# 2        SanDiego     False             True
# 3        SanDiego     False             True
# 4        SanDiego     False             True
# 5        SanDiego     False             True
# 6        SanDiego     False             True
# 7        SanDiego     False             True
# 8        SanDiego     False             True
# 9        SanDiego     False             True
# 10       SanDiego     False             True
# 11       SanDiego     False             True
# 12       SanDiego     False             True
# 13       SanDiego     False             True

# %% [markdown]
# ## check matches

# %%
# 1

# %%
print("Matches between logic and actual PC when baseline is supported:")
personilized_prediction_df["≈"].value_counts(normalize=True)
# Out:
# Matches between logic and actual PC when baseline is supported:
# True     0.667344
# False    0.332656
# Name: suggested_match, dtype: float64

# %%
print("Matches between logic and actual PC when baseline is NOT supported:")
personilized_prediction_df["suggested_no_base_match"].value_counts(normalize=True)
# Out:
# Matches between logic and actual PC when baseline is NOT supported:
# True     0.665611
# False    0.334389
# Name: suggested_no_base_match, dtype: float64

# %%
clean_personilized_prediction_df["bl_suggested"].value_counts(normalize=True)
# Out:
# True     0.937386
# False    0.062614
# Name: bl_suggested, dtype: float64

# %%
clean_personilized_prediction_df["bl_match"].value_counts(normalize=True)
# Out:
# True     0.86056
# False    0.13944
# Name: bl_match, dtype: float64

# %%
clean_personilized_prediction_df["suggested_match"].value_counts(normalize=True)
# Out:
# True     0.895763
# False    0.104237
# Name: suggested_match, dtype: float64

# %%
clean_personilized_prediction_df["suggested_no_base_match"].value_counts(normalize=True)
# Out:
# True     0.893437
# False    0.106563
# Name: suggested_no_base_match, dtype: float64

# %%
# 2

# %%
not_bl_df = clean_personilized_prediction_df[personilized_prediction_df["bl_suggested"] == False]
# Out:
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
not_bl_df["suggested_match"].value_counts(normalize=True)
# Out:
# True     0.714962
# False    0.285038
# Name: suggested_match, dtype: float64

# %%
# 3

# %%
clean_personilized_prediction_df[clean_personilized_prediction_df["suggested_match"] == True].value_counts(
    ["bl_suggested"], normalize=True)
# Out:
# bl_suggested
# True            0.950024
# False           0.049976
# dtype: float64

# %%
clean_personilized_prediction_df.value_counts(["bl_suggested", "suggested_match", "bl_match"], normalize=True)
# Out:
# bl_suggested  suggested_match  bl_match
# True          True             True        0.850996
#               False            False       0.086390
# False         True             False       0.044767
#               False            True        0.009565
#                                False       0.008283
# dtype: float64

# %%
clean_personilized_prediction_df[(clean_personilized_prediction_df["bl_suggested"] == True) & (
    clean_personilized_prediction_df["suggested_match"] == False)][["vessel", "reported", "bl_dest", "real_dest", ]][:30]
# Out:
#                        vessel       reported                   bl_dest  \
# 7    513a7b806ca0bbcb46a5a1e3         KH SHV  5358fc78b68ca120a07db7cb
# 51   513a7b806ca0bbcb46a5a1e3         CN NGB  5358fc78b68ca120a07db9f4
# 64   513a7b806ca0bbcb46a5a1e3         TH LCH  54880c9b2f16092e9efe8a43
# 83   513a7b806ca0bbcb46a5a1e3         CN SHA  5358fc78b68ca120a07dbcfb
# 99   513a7b806ca0bbcb46a5a1e3         VN SGN  5358fc78b68ca120a07dbaa9
# 119  513a7b806ca0bbcb46a5a1e3      JP TYO CW  5358fc78b68ca120a07dbcff
# 212  5153880066556bcfc5c43d11         FUZHOU  57c539e9447c1ee77504c390
# 226  5153880066556bcfc5c43d11         FUZHOU  57c539e9447c1ee77504c390
# 228  5153880066556bcfc5c43d11        XIA MEN  5358fc78b68ca120a07dbc52
# 254  5153880066556bcfc5c43d11         XIAMEN  5358fc78b68ca120a07dbc52
# 296  5153880066556bcfc5c43d11        XIA MEN  5358fc78b68ca120a07dbc52
# 323  5153880066556bcfc5c43d11        XIA MEN  5358fc78b68ca120a07dbc52
# 329  5153880066556bcfc5c43d11        XIA MEN  5358fc78b68ca120a07dbc52
# 356  5153880066556bcfc5c43d11         XIAMEN  5358fc78b68ca120a07dbc52
# 369  5153880066556bcfc5c43d11        XIA MEN  5358fc78b68ca120a07dbc52
# 387  5153880066556bcfc5c43d11        KEELUNG  5358fc78b68ca120a07dbc99
# 418  5153880066556bcfc5c43d11         XIAMEN  5358fc78b68ca120a07dbc52
# 560  5358fc78b68ca120a07db9f4     False 2022-03-01 00:00:00
# 577  5358fc78b68ca120a07db9f4     False 2021-09-18 21:25:24
# 592  5358fc78b68ca120a07dbca3     False 2021-11-14 13:07:26
# 611  54880a1a2f16092e9efe61e5     False 2022-02-02 03:53:10
# 624  5358fc78b68ca120a07db9f4     False 2022-04-01 00:00:00
#
#                                     found_destinations  \
# 7    [{'baseline': '5358fc78b68ca120a07db7cb', 'act...
# 51   [{'baseline': '5358fc78b68ca120a07db9f4', 'act...
# 64   [{'baseline': '54880c9b2f16092e9efe8a43', 'act...
# 83   [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 99   [{'baseline': '5358fc78b68ca120a07dbaa9', 'act...
# 119  [{'baseline': '5358fc78b68ca120a07dbcff', 'act...
# 212  [{'baseline': '57c539e9447c1ee77504c390', 'act...
# 226  [{'baseline': '57c539e9447c1ee77504c390', 'act...
# 228  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 254  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 296  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 323  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 329  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 356  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 369  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 387  [{'baseline': '5358fc78b68ca120a07dbc99', 'act...
# 418  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 437  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 450  [{'baseline': '5358fc78b68ca120a07dbc52', 'act...
# 464  [{'baseline': '5358fc78b68ca120a07dbce5', 'act...
# 513  [{'baseline': '5358fc78b68ca120a07dbc6e', 'act...
# 514  [{'baseline': '5358fc78b68ca120a07dbc6e', 'act...
# 526  [{'baseline': '5358fc78b68ca120a07dbc6e', 'act...
# 528  [{'baseline': '5358fc78b68ca120a07db8b9', 'act...
# 535  [{'baseline': '5358fc78b68ca120a07dbce5', 'act...
# 560  [{'baseline': '5358fc78b68ca120a07dbcfe', 'act...
# 577  [{'baseline': '553caeb6d4e6a49b3fb0d1e1', 'act...
# 592  [{'baseline': '5358fc78b68ca120a07dbca7', 'act...
# 611  [{'baseline': '5358fc78b68ca120a07dbd24', 'act...
# 624  [{'baseline': '5358fc78b68ca120a07db9b8', 'act...
#
#                                                    new  \
# 7       {'54880c9b2f16092e9efe8a3f': 1, 'baseline': 5}
# 51      {'5358fc78b68ca120a07dbcfb': 1, 'baseline': 8}
# 64                                    {'baseline': 14}
# 83                                    {'baseline': 15}
# 99     {'baseline': 21, '5358fc78b68ca120a07dbc52': 1}
# 119                                    {'baseline': 3}
# 212                                   {'baseline': 33}
# 226    {'baseline': 32, '5358fc78b68ca120a07dbc52': 1}
# 228                                   {'baseline': 25}
# 254    {'baseline': 69, '5358fc78b68ca120a07dbc09': 1}
# 296    {'baseline': 27, '5358fc78b68ca120a07dbc99': 1}
# 323    {'baseline': 28, '5358fc78b68ca120a07dbc99': 2}
# 329  {'baseline': 29, '5358fc78b68ca120a07dbc99': 2...
# 356    {'baseline': 54, '5358fc78b68ca120a07dbc09': 1}
# 369  {'baseline': 32, '5358fc78b68ca120a07dbc99': 3...
# 387    {'baseline': 74, '5358fc78b68ca120a07dbc52': 1}
# 418    {'baseline': 44, '5358fc78b68ca120a07dbc09': 2}
# 437  {'baseline': 43, '5358fc78b68ca120a07dbc09': 2...
# 450  {'baseline': 43, '5358fc78b68ca120a07dbc09': 3...
# 464                                    {'baseline': 8}
# 513                                    {'baseline': 9}
# 514     {'baseline': 9, '5358fc78b68ca120a07db8b9': 1}
# 526    {'baseline': 11, '5358fc78b68ca120a07db8b9': 2}
# 528                                    {'baseline': 9}
# 535                                    {'baseline': 2}
# 560                                    {'baseline': 1}
# 577     {'baseline': 2, '54880a1a2f16092e9efe61e5': 1}
# 592                                    {'baseline': 1}
# 611                                    {'baseline': 7}
# 624                                    {'baseline': 3}
#
#                suggested_dest      suggested_no_bl_dest  suggested_match_2  \
# 7    5358fc78b68ca120a07db7cb  5358fc78b68ca120a07db7cb              False
# 51   5358fc78b68ca120a07db9f4  5358fc78b68ca120a07db9f4              False
# 64   54880c9b2f16092e9efe8a43  54880c9b2f16092e9efe8a43              False
# 83   5358fc78b68ca120a07dbcfb  5358fc78b68ca120a07dbcfb              False
# 99   5358fc78b68ca120a07dbaa9  5358fc78b68ca120a07dbaa9              False
# 119  5358fc78b68ca120a07dbcff  5358fc78b68ca120a07dbcff              False
# 212  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390              False
# 226  57c539e9447c1ee77504c390  57c539e9447c1ee77504c390              False
# 228  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 254  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 296  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 323  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 329  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 356  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 369  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 387  5358fc78b68ca120a07dbc99  5358fc78b68ca120a07dbc99              False
# 418  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 437  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 450  5358fc78b68ca120a07dbc52  5358fc78b68ca120a07dbc52              False
# 464  5358fc78b68ca120a07dbce5  5358fc78b68ca120a07dbce5              False
# 513  5358fc78b68ca120a07dbc6e  5358fc78b68ca120a07dbc6e              False
# 514  5358fc78b68ca120a07dbc6e  5358fc78b68ca120a07dbc6e              False
# 526  5358fc78b68ca120a07dbc6e  5358fc78b68ca120a07dbc6e              False
# 528  5358fc78b68ca120a07db8b9  5358fc78b68ca120a07db8b9              False
# 535  5358fc78b68ca120a07dbce5  5358fc78b68ca120a07dbce5              False
# 560  5358fc78b68ca120a07dbcfe  5358fc78b68ca120a07dbcfe              False
# 577  553caeb6d4e6a49b3fb0d1e1  553caeb6d4e6a49b3fb0d1e1              False
# 592  5358fc78b68ca120a07dbca7  5358fc78b68ca120a07dbca7              False
# 611  5358fc78b68ca120a07dbd24  5358fc78b68ca120a07dbd24              False
# 624  5358fc78b68ca120a07db9b8  5358fc78b68ca120a07db9b8              False
#
#      suggested_no_base_match  bl_suggested  suggested_match
# 7                      False          True            False
# 51                     False          True            False
# 64                     False          True            False
# 83                     False          True            False
# 99                     False          True            False
# 119                    False          True            False
# 212                    False          True            False
# 226                    False          True            False
# 228                    False          True            False
# 254                    False          True            False
# 296                    False          True            False
# 323                    False          True            False
# 329                    False          True            False
# 356                    False          True            False
# 369                    False          True            False
# 387                    False          True            False
# 418                    False          True            False
# 437                    False          True            False
# 450                    False          True            False
# 464                    False          True            False
# 513                    False          True            False
# 514                    False          True            False
# 526                    False          True            False
# 528                    False          True            False
# 535                    False          True            False
# 560                    False          True            False
# 577                    False          True            False
# 592                    False          True            False
# 611                    False          True            False
# 624                    False          True            False

# %%
clean_personilized_prediction_df.value_counts(["bl_suggested", "suggested_match", "bl_match"], normalize=True)

# %%
pd.crosstab(clean_personilized_prediction_df[["bl_match"]], clean_personilized_prediction_df[["suggested_match"]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1692         blocks = form_blocks(arrays, names, axes)
# -> 1693         mgr = BlockManager(blocks, axes)
#    1694         mgr._consolidate_inplace()
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     328             if block.shape[1:] != mgr_shape[1:]:
# --> 329                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     330         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (1, 2), indices imply (408069, 2)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-e8a90be111a4> in <module>
# ----> 1 pd.crosstab(clean_personilized_prediction_df[["bl_match"]], clean_personilized_prediction_df[["suggested_match"]])
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     604     from pandas import DataFrame
#     605
# --> 606     df = DataFrame(data, index=common_idx)
#     607     original_df_cols = df.columns
#     608
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      91     axes = [columns, index]
#      92
# ---> 93     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      94
#      95
#
# /mnt/xvdb/python-envs/research_lib___dev/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1695         return mgr
#    1696     except ValueError as e:
# -> 1697         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1698
#    1699
#
# ValueError: Shape of passed values is (1, 2), indices imply (408069, 2)

# %%
# 4

# %%
personilized_prediction_df[(personilized_prediction_df["bl_match"] == False) & (
    personilized_prediction_df["suggested_match"] == False)
                          ]
# Out:
#                           vessel       reported                   bl_dest  \
# 7       513a7b806ca0bbcb46a5a1e3         KH SHV  5358fc78b68ca120a07db7cb
# 51      513a7b806ca0bbcb46a5a1e3         CN NGB  5358fc78b68ca120a07db9f4
# 64      513a7b806ca0bbcb46a5a1e3         TH LCH  54880c9b2f16092e9efe8a43
# 83      513a7b806ca0bbcb46a5a1e3         CN SHA  5358fc78b68ca120a07dbcfb
# 99      513a7b806ca0bbcb46a5a1e3         VN SGN  5358fc78b68ca120a07dbaa9
# ...                          ...            ...                       ...
# 547714  62d6e20e6e5c10c029df7f37         ID SRI  5358fc78b68ca120a07db74f
# 547715  62d6e20e6e5c10c029df7f37         ID SRI  5358fc78b68ca120a07db74f
# 547716  62d6e20e6e5c10c029df7f37         ID SRI  5358fc78b68ca120a07db74f
# 547733  62d6e20e6e5c10c029df7f37         ID SRI  5358fc78b68ca120a07db74f
# 547735  62d6e20e6e5c10c029df7f37  TIANJIN,CHINA  5358fc78b68ca120a07dbcd2
#
#                        real_dest  bl_match                  ts  \
# 7       54880c9b2f16092e9efe8a43     False 2021-09-23 05:49:21
# 51      5358fc78b68ca120a07dbcfb     False 2022-01-02 16:23:28
# 64      5358fc77b68ca120a07db205     False 2022-02-01 00:00:00
# 83      5358fc78b68ca120a07db9f4     False 2022-03-16 04:59:07
# 99      5358fc78b68ca120a07db7cb     False 2022-05-01 00:00:00
# ...                          ...       ...                 ...
# 547714  5358fc78b68ca120a07dbc01     False 2022-04-16 05:20:30
# 547715  5358fc78b68ca120a07dbc01     False 2022-05-01 00:00:00
# 547716  5358fc78b68ca120a07dbc01     False 2022-05-03 00:00:00
# 547733  5358fc78b68ca120a07dbc01     False 2022-07-04 00:27:42
# 547735  5358fc78b68ca120a07dbc01     False 2022-07-19 03:34:34
#
#                                        found_destinations  \
# 7       [{'baseline': '5358fc78b68ca120a07db7cb', 'act...
# 51      [{'baseline': '5358fc78b68ca120a07db9f4', 'act...
# 64      [{'baseline': '54880c9b2f16092e9efe8a43', 'act...
# 83      [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 99      [{'baseline': '5358fc78b68ca120a07dbaa9', 'act...
# ...                                                   ...
# 547714  [{'baseline': '5358fc78b68ca120a07db74f', 'act...
# 547715  [{'baseline': '5358fc78b68ca120a07db74f', 'act...
# 547716  [{'baseline': '5358fc78b68ca120a07db74f', 'act...
# 547733  [{'baseline': '5358fc78b68ca120a07db74f', 'act...
# 547735                                                 []
#
#                                                     new  \
# 7        {'54880c9b2f16092e9efe8a3f': 1, 'baseline': 5}
# 51       {'5358fc78b68ca120a07dbcfb': 1, 'baseline': 8}
# 64                                     {'baseline': 14}
# 83                                     {'baseline': 15}
# 99      {'baseline': 21, '5358fc78b68ca120a07dbc52': 1}
# ...                                                 ...
# 547714  {'baseline': 14, '5358fc78b68ca120a07dbc01': 1}
# 547715  {'baseline': 14, '5358fc78b68ca120a07dbc01': 2}
# 547716  {'baseline': 14, '5358fc78b68ca120a07dbc01': 3}
# 547733  {'baseline': 21, '5358fc78b68ca120a07dbc01': 4}
# 547735                                             None
#
#                   suggested_dest      suggested_no_bl_dest  suggested_match  \
# 7       5358fc78b68ca120a07db7cb  5358fc78b68ca120a07db7cb            False
# 51      5358fc78b68ca120a07db9f4  5358fc78b68ca120a07db9f4            False
# 64      54880c9b2f16092e9efe8a43  54880c9b2f16092e9efe8a43            False
# 83      5358fc78b68ca120a07dbcfb  5358fc78b68ca120a07dbcfb            False
# 99      5358fc78b68ca120a07dbaa9  5358fc78b68ca120a07dbaa9            False
# ...                          ...                       ...              ...
# 547714  5358fc78b68ca120a07db74f  5358fc78b68ca120a07db74f            False
# 547715  5358fc78b68ca120a07db74f  5358fc78b68ca120a07db74f            False
# 547716  5358fc78b68ca120a07db74f  5358fc78b68ca120a07db74f            False
# 547733  5358fc78b68ca120a07db74f  5358fc78b68ca120a07db74f            False
# 547735                      None                      None            False
#
#         suggested_no_base_match  bl_suggested
# 7                         False          True
# 51                        False          True
# 64                        False          True
# 83                        False          True
# 99                        False          True
# ...                         ...           ...
# 547714                    False          True
# 547715                    False          True
# 547716                    False          True
# 547733                    False          True
# 547735                    False         False
#
# [85282 rows x 13 columns]

# %%
# 5

# %%
bl_match_df = clean_personilized_prediction_df[clean_personilized_prediction_df["bl_match"] == True][[
    "vessel", "reported", "bl_dest", "real_dest", "bl_match", TS, "suggested_dest"]]

# %%
suggested_match_df = clean_personilized_prediction_df[clean_personilized_prediction_df["suggested_match"] == True][[
    "vessel", "reported", "bl_dest", "real_dest", "bl_match", TS, "suggested_dest"]]

# %%
bl_match_df.merge(suggested_match_df, on=[
                  "vessel", "reported", TS, "bl_dest", "real_dest", "suggested_dest"], how="outer")[:50]
# Out:
#                       vessel       reported                   bl_dest  \
# 0   513a7b806ca0bbcb46a5a1e3         JP SBK  5358fc78b68ca120a07dbbc9
# 1   513a7b806ca0bbcb46a5a1e3       JP OSA H  5358fc78b68ca120a07dbcbb
# 2   513a7b806ca0bbcb46a5a1e3         JP UKB  5358fc78b68ca120a07dbc9e
# 3   513a7b806ca0bbcb46a5a1e3         KR PUS  5358fc78b68ca120a07dbc71
# 22  5358fc78b68ca120a07dbcfb       True 2021-11-03 23:06:40
# 23  5358fc78b68ca120a07dbcf1       True 2021-11-06 18:11:42
# 24  5358fc78b68ca120a07dbcff       True 2021-11-10 00:27:44
# 25  5358fc78b68ca120a07dbcff       True 2021-11-10 07:08:59
# 26  5358fc78b68ca120a07dbcff       True 2021-11-10 18:26:59
# 27  5358fc78b68ca120a07dbd00       True 2021-11-11 08:44:34
# 28  5358fc78b68ca120a07dbcfb       True 2021-11-11 18:30:29
# 29  5358fc78b68ca120a07dbc52       True 2021-11-15 17:56:59
# 30  5358fc78b68ca120a07dbaa9       True 2021-11-18 08:08:58
# 31  54880c9b2f16092e9efe8a3f       True 2021-11-23 02:08:00
# 32  54880c9b2f16092e9efe8a43       True 2021-11-27 01:02:59
# 33  5358fc77b68ca120a07db205       True 2021-11-28 03:44:00
# 34  5358fc77b68ca120a07db205       True 2021-12-01 00:00:00
# 35  5358fc77b68ca120a07db6b1       True 2021-12-02 16:51:00
# 36  5358fc78b68ca120a07dbc92       True 2021-12-07 13:03:05
# 37  5358fc77b68ca120a07db0bb       True 2021-12-11 02:35:44
# 38  53720b4f57b2d3980edf9bfa       True 2021-12-11 17:07:07
# 39  5358fc78b68ca120a07dbce5       True 2021-12-17 11:08:58
# 40  5358fc78b68ca120a07dbaa9       True 2021-12-20 13:08:58
# 41  5358fc78b68ca120a07db7cb       True 2021-12-23 17:44:32
# 42  54880c9b2f16092e9efe8a3f       True 2021-12-27 04:27:14
# 43  54880c9b2f16092e9efe8a43       True 2021-12-29 23:54:46
# 44  5358fc78b68ca120a07dbaa9       True 2021-12-31 02:12:46
# 45  5358fc78b68ca120a07dbaa9       True 2022-01-01 00:00:00
# 46  5358fc78b68ca120a07dbcfb       True 2022-01-08 07:06:46
# 47  5358fc78b68ca120a07db9f4       True 2022-01-08 20:06:46
# 48  5358fc78b68ca120a07dbcf1       True 2022-01-11 11:54:42
# 49  5358fc78b68ca120a07dbcff       True 2022-01-13 10:48:47
#
#               suggested_dest bl_match_y
# 0   5358fc78b68ca120a07dbbc9       True
# 1   5358fc78b68ca120a07dbcbb       True
# 2   5358fc78b68ca120a07dbc9e       True
# 3   5358fc78b68ca120a07dbc71       True
# 4   5358fc78b68ca120a07dbcfb       True
# 5   5358fc78b68ca120a07dbce5       True
# 6   5358fc78b68ca120a07dbaa9       True
# 7   54880c9b2f16092e9efe8a43       True
# 8   5358fc77b68ca120a07db205       True
# 9   5358fc77b68ca120a07db205       True
# 10  5358fc77b68ca120a07db6b1       True
# 11  5358fc78b68ca120a07dbc92       True
# 12  5358fc77b68ca120a07db0bb       True
# 13  53720b4f57b2d3980edf9bfa       True
# 14  5358fc78b68ca120a07dbcfb       True
# 15  5358fc78b68ca120a07dbaa9       True
# 16  5358fc78b68ca120a07db7cb       True
# 17  54880c9b2f16092e9efe8a3f       True
# 18  54880c9b2f16092e9efe8a43       True
# 19  5358fc78b68ca120a07dbaa9       True
# 20  5358fc78b68ca120a07db9f4       True
# 21  5358fc78b68ca120a07db9f4       True
# 22  5358fc78b68ca120a07dbcfb       True
# 23  5358fc78b68ca120a07dbcf1       True
# 24  5358fc78b68ca120a07dbcff       True
# 25  5358fc78b68ca120a07dbcff       True
# 26  5358fc78b68ca120a07dbcff       True
# 27  5358fc78b68ca120a07dbd00       True
# 28  5358fc78b68ca120a07dbcfb       True
# 29  5358fc78b68ca120a07dbc52       True
# 30  5358fc78b68ca120a07dbaa9       True
# 31  54880c9b2f16092e9efe8a3f       True
# 32  54880c9b2f16092e9efe8a43       True
# 33  5358fc77b68ca120a07db205       True
# 34  5358fc77b68ca120a07db205       True
# 35  5358fc77b68ca120a07db6b1       True
# 36  5358fc78b68ca120a07dbc92       True
# 37  5358fc77b68ca120a07db0bb       True
# 38  53720b4f57b2d3980edf9bfa       True
# 39  5358fc78b68ca120a07dbce5       True
# 40  5358fc78b68ca120a07dbaa9       True
# 41  5358fc78b68ca120a07db7cb       True
# 42  54880c9b2f16092e9efe8a3f       True
# 43  54880c9b2f16092e9efe8a43       True
# 44  5358fc78b68ca120a07dbaa9       True
# 45  5358fc78b68ca120a07dbaa9       True
# 46  5358fc78b68ca120a07dbcfb       True
# 47  5358fc78b68ca120a07db9f4       True
# 48  5358fc78b68ca120a07dbcf1       True
# 49  5358fc78b68ca120a07dbcff       True

# %%
clean_personilized_prediction_df[(clean_personilized_prediction_df["bl_match"] == True) & (
    clean_personilized_prediction_df["suggested_match"] == False)]
# Out:
#                           vessel       reported                   bl_dest  \
# 871     54878d00789f4e8acb25a84d       YANGSHAN  5358fc78b68ca120a07dbcfb
# 898     54878d00789f4e8acb25a84d  KING ABDULLAH  57459203000cad0168e18723
# 1005    548e2480b4814836268bd428          GBFXT  5358fc78b68ca120a07dbc82
# 1122    54fe340096f422917a4fe00d          SINES  5358fc78b68ca120a07db7d1
# 1254    551c8680061d1b443e31deeb         CO BUN  55b5d0da2f9be5a605f67b45
# ...                          ...            ...                       ...
# 545780  604a1a5fba6708076e1017fa   SGSIN(PWBGA)  591852ef8d54876cb3f80f2d
# 546810  609153ee2e6583434c994910  EGPSD > MYPKG  5fe891a959431f434b3bbc55
# 546822  609153ee2e6583434c994910  EGSUZ > FRDKK  5358fc78b68ca120a07dba53
# 547007  60a3b5c4eae7152674710ef5      JP UKB RS  5358fc78b68ca120a07dbc9e
# 547233  60bfb304a7e8d1021bc452ca          MYPEN  5358fc78b68ca120a07dbb7a
#
#                        real_dest  bl_match                  ts  \
# 871     5358fc78b68ca120a07dbcfb      True 2021-10-27 01:33:47
# 898     57459203000cad0168e18723      True 2022-02-01 00:00:00
# 1005    5358fc78b68ca120a07dbc82      True 2022-03-10 04:45:14
# 1122    5358fc78b68ca120a07db7d1      True 2021-10-24 08:44:25
# 1254    55b5d0da2f9be5a605f67b45      True 2022-02-01 00:00:00
# ...                          ...       ...                 ...
# 545780  591852ef8d54876cb3f80f2d      True 2022-07-01 00:00:00
# 546810  5fe891a959431f434b3bbc55      True 2022-07-02 19:37:21
# 546822  5358fc78b68ca120a07dba53      True 2022-08-13 10:29:56
# 547007  5358fc78b68ca120a07dbc9e      True 2022-07-03 19:31:15
# 547233  5358fc78b68ca120a07dbb7a      True 2022-07-15 07:46:15
#
#                                        found_destinations  \
# 871     [{'baseline': '5358fc78b68ca120a07dbcfb', 'act...
# 898     [{'baseline': '57459203000cad0168e18723', 'act...
# 1005    [{'baseline': '5358fc78b68ca120a07dbc82', 'act...
# 1122    [{'baseline': '5358fc78b68ca120a07db7d1', 'act...
# 1254    [{'baseline': '55b5d0da2f9be5a605f67b45', 'act...
# ...                                                   ...
# 545780  [{'baseline': '591852ef8d54876cb3f80f2d', 'act...
# 546810  [{'baseline': '5fe891a959431f434b3bbc55', 'act...
# 546822  [{'baseline': '5358fc78b68ca120a07dba53', 'act...
# 547007  [{'baseline': '5358fc78b68ca120a07dbc9e', 'act...
# 547233  [{'baseline': '5358fc78b68ca120a07dbb7a', 'act...
#
#                                                       new  \
# 871                       {'5de771cb9cfeec59a0141541': 1}
# 898     {'54880a1a2f16092e9efe61e5': 4, '591852ef8d548...
# 1005                      {'5358fc78b68ca120a07dbcf7': 2}
# 1122    {'54880a1a2f16092e9efe61e5': 1, '5358fc78b68ca...
# 1254                      {'54880a1a2f16092e9efe61e4': 3}
# ...                                                   ...
# 545780  {'54880a1a2f16092e9efe61e5': 2, '5358fc78b68ca...
# 546810                    {'54880a1a2f16092e9efe61e5': 1}
# 546822  {'54880a1a2f16092e9efe61e5': 2, '5358fc78b68ca...
# 547007                    {'53720b4f57b2d3980edf9bfa': 1}
# 547233                    {'591852ef8d54876cb3f80f2d': 1}
#
#                   suggested_dest      suggested_no_bl_dest  suggested_match_2  \
# 871     5de771cb9cfeec59a0141541  5de771cb9cfeec59a0141541              False
# 898     54880a1a2f16092e9efe61e5  54880a1a2f16092e9efe61e5              False
# 1005    5358fc78b68ca120a07dbcf7  5358fc78b68ca120a07dbcf7              False
# 1122    54880a1a2f16092e9efe61e5  54880a1a2f16092e9efe61e5              False
# 1254    54880a1a2f16092e9efe61e4  54880a1a2f16092e9efe61e4              False
# ...                          ...                       ...                ...
# 545780  54880a1a2f16092e9efe61e5  54880a1a2f16092e9efe61e5              False
# 546810  54880a1a2f16092e9efe61e5  54880a1a2f16092e9efe61e5              False
# 546822  54880a1a2f16092e9efe61e5  54880a1a2f16092e9efe61e5              False
# 547007  53720b4f57b2d3980edf9bfa  53720b4f57b2d3980edf9bfa              False
# 547233  591852ef8d54876cb3f80f2d  591852ef8d54876cb3f80f2d              False
#
#         suggested_no_base_match  bl_suggested  suggested_match
# 871                       False         False            False
# 898                       False         False            False
# 1005                      False         False            False
# 1122                      False         False            False
# 1254                      False         False            False
# ...                         ...           ...              ...
# 545780                    False         False            False
# 546810                    False         False            False
# 546822                    False         False            False
# 547007                    False         False            False
# 547233                    False         False            False
#
# [3903 rows x 14 columns]

# %%
(3903 / len(clean_personilized_prediction_df
# Out:
# 0.9564558934886012
